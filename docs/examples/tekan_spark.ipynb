# %%
# %reload_ext autoreload
# %autoreload 2

from MTPHandler.core import Plate

# %%
path = "/Users/max/Documents/GitHub/MTPHandler/tests/data/tekan_spark.xlsx"

plate = Plate.from_file(path=path)

# %%
plate.visualize(zoom=True)
