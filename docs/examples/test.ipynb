# %%
# %reload_ext autoreload
# %autoreload 2

from MTPHandler.core import Plate
from MTPHandler.readers.factory import MTPReaderFactory

# %%
# Define measurement conditions
ph = 7.4
temperature = 37
wavelength = 550

path = "../../tests/data/magellan.xlsx"

ph = 7.0
wavelength = 450.0

plate = MTPReaderFactory.read(
    path=path,
    ph=ph,
    wavelength=wavelength,
)

print(plate)
# Out:
# Plate
# ├── id = 09becb8d-1e6f-4701-bf9c-765fe0a625ae
# ├── n_rows = 8
# ├── n_cols = 12
# ├── date_measured = 2023-08-16 16:12:40
# ├── times = [0.0, 900.0, 1802.0, 2700.0, 3600.0, ...]
# ├── time_unit
# │   └── Unit
# │       ├── id = 8b4611ef-4bbd-4913-a781-31cfa5b25348
# │       ├── name = s
# │       └── bases
# │           └── 0
# │               └── BaseUnit
# │                   ├── scale = 1.0
# │                   ├── kind = s
# │                   └── exponent = 1.0
# ├── temperatures = [37.1, 37.2, 37.1, 37.2, 36.9, ...]
# ├── temperature_unit
# │   └── Unit
# │       ├── id = 637385d7-6185-411e-8074-5584826f749e
# │       ├── name = C
# │       └── bases
# │           └── 0
# │               └── BaseUnit
# │                   ├── scale = 1.0
# │                   ├── kind = A
# │                   └── exponent = 1.0
# └── wells
#     ├── 0
#     │   └── Well
#     │       ├── id = A4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = cc3e4e3e-d585-4bac-9c72-596727bafda4
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 3473dd38-487b-436e-9411-db3186d32f82
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.7409, 2.7371, 2.7344, 2.727, 2.7222, ...]
#     ├── 1
#     │   └── Well
#     │       ├── id = A5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 3340c5cf-2f53-4cbc-b29b-5fa682935b00
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 243b7e62-f089-4237-b7db-80edc8c9fdbc
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0645, -0.0622, -0.0618, -0.0642, -0.0658, ...]
#     ├── 2
#     │   └── Well
#     │       ├── id = A6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 72ac2c31-b3b4-47f3-ae09-9027cc30ab5a
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 74ad6b47-6e95-49a5-9c08-f30ef105117f
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.23, 0.2294, 0.2275, 0.225, 0.2211, ...]
#     ├── 3
#     │   └── Well
#     │       ├── id = A7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 60b87e55-006a-437a-90d1-46d959222c9a
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 3cb753d7-78a2-4ec5-a137-2d390794e200
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.2477, 1.2472, 1.2422, 1.2361, 1.232, ...]
#     ├── 4
#     │   └── Well
#     │       ├── id = A8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 9e3b1126-5f3c-4c82-8531-63f2c1a06053
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = d008cba3-8968-4c55-bdf1-307f03755290
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.2356, 2.2346, 2.2302, 2.2236, 2.2176, ...]
#     ├── 5
#     │   └── Well
#     │       ├── id = A9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 632f0e23-d8ea-4ae0-b02b-9ffee104cebe
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 6f2d2782-ece8-4de9-a1d0-34563f83c45b
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.1345, 3.1269, 3.1375, 3.1251, 3.1376, ...]
#     ├── 6
#     │   └── Well
#     │       ├── id = A10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = adc09a1a-98c2-47c0-9923-f327602f67d6
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 92df35d6-a901-4fb7-b4c4-5a4e20b90625
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.1628, 3.1554, 3.1636, 3.1568, 3.1663, ...]
#     ├── 7
#     │   └── Well
#     │       ├── id = A11
#     │       ├── ph = 450.0
#     │       ├── x_pos = 10
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 8473a8c8-6e89-4583-bbc0-46d81321fe6a
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 305747e4-0cc9-49f3-ba31-27a3c181921a
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.1308, 3.1247, 3.1323, 3.1239, 3.1333, ...]
#     ├── 8
#     │   └── Well
#     │       ├── id = A12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 0
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = bd71628a-8ba6-4315-a78d-741a2e99ae55
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 3df34a3c-eb8d-4305-bbb9-b3c408247bbf
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.2064, 3.1956, 3.2051, 3.2074, 3.2031, ...]
#     ├── 9
#     │   └── Well
#     │       ├── id = B4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = c6698f96-4b47-4567-a2a9-33932bb087d5
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 5d8acc72-4ec8-489a-b00e-dbe6febec187
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.6706, 2.6689, 2.6671, 2.662, 2.6579, ...]
#     ├── 10
#     │   └── Well
#     │       ├── id = B5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 41ec4887-b102-479a-8631-3d7cac4a4b9b
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = d61059a6-0252-42d6-a07d-e165086e313d
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.052, -0.0503, -0.0499, -0.0508, -0.0509, ...]
#     ├── 11
#     │   └── Well
#     │       ├── id = B6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 34b269e2-70c0-4cfc-8111-3c2a3cf48cd8
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = f7d292c8-aa75-4669-9bb5-397eeeec667c
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.2307, 0.2318, 0.228, 0.2251, 0.2237, ...]
#     ├── 12
#     │   └── Well
#     │       ├── id = B7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 2e36afd7-a345-4733-a768-aa90199752b9
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = c39d0036-5351-49a3-8383-f60e3982d378
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.2522, 1.2518, 1.249, 1.2439, 1.24, ...]
#     ├── 13
#     │   └── Well
#     │       ├── id = B8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = c1d78784-4efd-4fb0-bd88-c9244212aec4
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = eee58958-61dc-439a-b9d8-845a3fe1005b
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.2376, 2.2357, 2.2322, 2.226, 2.2192, ...]
#     ├── 14
#     │   └── Well
#     │       ├── id = B9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 048f3ab2-1898-4d27-867d-bbd225d7bc25
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = ac9a80a2-97b7-41e8-ab8f-3a5c27b5434c
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9437, 2.9352, 2.9449, 2.9431, 2.9398, ...]
#     ├── 15
#     │   └── Well
#     │       ├── id = B10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = d6569c48-b6c8-4cf4-b581-83c95351cd92
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = dcd7ad8a-d12b-47a3-8b5a-8d6d202d7410
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9484, 2.9436, 2.9541, 2.9459, 2.9616, ...]
#     ├── 16
#     │   └── Well
#     │       ├── id = B11
#     │       ├── ph = 450.0
#     │       ├── x_pos = 10
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 4cceebf7-1991-4aa1-b383-34f7149ea0b7
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = fcb3db40-f86e-4925-a24e-3a6b6ad6072d
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9348, 2.9221, 2.9331, 2.9435, 2.9345, ...]
#     ├── 17
#     │   └── Well
#     │       ├── id = B12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 1
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 58e8ddbc-11ab-4f9b-a76c-a1371e112a21
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 9ceeb5ca-6a1e-4c52-ba65-60bb59f644fc
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.1541, 3.1371, 3.1454, 3.1578, 3.1512, ...]
#     ├── 18
#     │   └── Well
#     │       ├── id = E8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = e0a35368-fa20-44b6-aab1-12e031b52528
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 7803e65d-12a5-41c1-aefd-f0d2b80ff34e
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.6871, 2.6848, 2.6816, 2.6793, 2.6681, ...]
#     ├── 19
#     │   └── Well
#     │       ├── id = C5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = f6afc358-f4fc-4600-8890-46dd2fe95876
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = dda5e688-4382-4ba9-b434-5a4b17791f58
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0576, -0.0569, -0.0574, -0.0584, -0.0581, ...]
#     ├── 20
#     │   └── Well
#     │       ├── id = C6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 93d90066-d079-4e79-b1b0-2c04d4218e23
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 4c60d3b4-16cb-4baa-a45e-3ed659dca048
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.2291, 0.2311, 0.2278, 0.2243, 0.2222, ...]
#     ├── 21
#     │   └── Well
#     │       ├── id = C7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 477469f8-bbbc-41e7-a2ae-0bdd4df1890e
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = df8c86e5-ec58-48a6-9b2b-7d6c1a3126d8
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.2501, 1.2499, 1.2466, 1.2406, 1.2373, ...]
#     ├── 22
#     │   └── Well
#     │       ├── id = C8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = fcafbe31-834a-4aa5-8abe-8e3f9e713c63
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 2851bab8-ff69-4d99-9bed-a624a0688423
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.3136, 2.3141, 2.3097, 2.303, 2.2946, ...]
#     ├── 23
#     │   └── Well
#     │       ├── id = C9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 007182a8-b9ec-4cad-b138-ae83bd063696
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 465a1718-cc44-4a9e-9c95-783ad27f0050
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9273, 2.9377, 2.9374, 2.9266, 2.9347, ...]
#     ├── 24
#     │   └── Well
#     │       ├── id = C10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = d5a52e89-0dad-48a1-9813-415b22052f16
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = f303766d-743e-4c88-b367-03304de1bc98
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.929, 2.9243, 2.929, 2.9274, 2.9381, ...]
#     ├── 25
#     │   └── Well
#     │       ├── id = C11
#     │       ├── ph = 450.0
#     │       ├── x_pos = 10
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 711d33f9-3e96-438b-94e5-617895d63e5b
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 6bd2aa4b-684b-4c18-9416-a6b07b50f658
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9311, 2.9236, 2.9293, 2.9294, 2.9318, ...]
#     ├── 26
#     │   └── Well
#     │       ├── id = C12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 2
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 88579a31-e7ea-4ec3-be17-3702dd7b37d1
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 670a3d58-212c-4a68-a1ed-74eff420c514
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.1041, 3.0966, 3.1153, 3.1024, 3.1144, ...]
#     ├── 27
#     │   └── Well
#     │       ├── id = F8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 66f6bcde-65a7-4519-b595-ae516666c72f
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = e6500866-a5fd-454e-94aa-c44ab9c74302
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.6902, 2.6869, 2.6862, 2.6823, 2.6732, ...]
#     ├── 28
#     │   └── Well
#     │       ├── id = D5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 5ad7c21d-8b86-4cb1-a001-81ed3fb1558b
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 81b4bac1-86d0-44c6-9821-a4b1e7bcfa05
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0567, -0.0538, -0.0543, -0.0549, -0.0552, ...]
#     ├── 29
#     │   └── Well
#     │       ├── id = D6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 14ede39c-c5af-4216-a8f3-483076f63337
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = f2c9fa22-6cfd-4b1d-b623-027365ace46e
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.2319, 0.2334, 0.2306, 0.2282, 0.2267, ...]
#     ├── 30
#     │   └── Well
#     │       ├── id = D7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 70961f51-6569-4e4e-846e-191b12df2b3c
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 9bc3e3a5-6c4d-4c2c-84ac-bc2ee902e390
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.2068, 1.2088, 1.2039, 1.1984, 1.1945, ...]
#     ├── 31
#     │   └── Well
#     │       ├── id = D8
#     │       ├── ph = 450.0
#     │       ├── x_pos = 7
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 37402a4b-b802-4692-8c07-c9cd38b2cc87
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 61c1fc87-2bbf-419b-8407-9094ff2e4113
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.2821, 2.2808, 2.2791, 2.2713, 2.2658, ...]
#     ├── 32
#     │   └── Well
#     │       ├── id = D9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 735bae17-e65b-497d-a1f7-78bde7776e07
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = d1cc8fb3-2266-416e-a70a-ef8a05ac581a
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9351, 2.9375, 2.9455, 2.9402, 2.9382, ...]
#     ├── 33
#     │   └── Well
#     │       ├── id = D10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 2dae3435-9c29-4276-8f1e-f98533c7b78e
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = ecf2cacf-34e9-44be-80d7-ee2f3eaed060
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9514, 2.9405, 2.9493, 2.9484, 2.9485, ...]
#     ├── 34
#     │   └── Well
#     │       ├── id = D11
#     │       ├── ph = 450.0
#     │       ├── x_pos = 10
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = d268bef1-9c2f-4cd0-828b-fe4a2b4c6003
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 763b7e6a-8fa5-4cb4-bacb-c58fca3bfe2d
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9395, 2.9224, 2.9388, 2.9412, 2.9417, ...]
#     ├── 35
#     │   └── Well
#     │       ├── id = D12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 3
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 8fbdbb69-ce35-477b-a969-b3d58ae06808
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 09634acf-fe18-4745-9e76-f804ee2c4500
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.0946, 3.0809, 3.0938, 3.0941, 3.0991, ...]
#     ├── 36
#     │   └── Well
#     │       ├── id = E4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 96f469e9-3ca7-4d92-9d52-ad0d96ddfab4
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 68be70fb-bb2e-474a-9ba3-dbb05c16175e
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0431, -0.0407, -0.0407, -0.0397, -0.039, ...]
#     ├── 37
#     │   └── Well
#     │       ├── id = E5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = e13d2eb5-a946-4648-9acb-ff129c88f5dc
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = c73dd5a2-da4a-491e-970d-d08b952111b2
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0262, -0.0245, -0.025, -0.0271, -0.0274, ...]
#     ├── 38
#     │   └── Well
#     │       ├── id = E6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 12847019-ce54-43d0-a4c4-693223dce53d
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = d0f6e608-56db-4f34-a177-e1dc998b85f7
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.579, 0.5806, 0.5777, 0.5727, 0.5697, ...]
#     ├── 39
#     │   └── Well
#     │       ├── id = E7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = ab82d101-5d66-4ca4-8cb6-5cf02876385c
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = a0e9dd36-02f8-4a4b-9867-b134825c2d7f
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.7883, 1.7865, 1.7828, 1.7752, 1.7693, ...]
#     ├── 40
#     │   └── Well
#     │       ├── id = E9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 28bc918f-61ad-488a-a6c0-7c85b47dabbc
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = ea8a354b-38b6-4859-b238-1902390be3cb
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9347, 2.9302, 2.9384, 2.9355, 2.9506, ...]
#     ├── 41
#     │   └── Well
#     │       ├── id = E10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 91576d0d-8a2d-4dbb-84d5-17196e5cc2aa
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = b65d18eb-7a50-4986-bed3-9b6f69c1bc28
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9395, 2.922, 2.9295, 2.9322, 2.9316, ...]
#     ├── 42
#     │   └── Well
#     │       ├── id = E12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 4
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = a1e4f6aa-8948-40e9-a476-29f40c3ff1bf
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 728f33d6-d38c-45b6-a649-db779b9ebc64
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0423, -0.0384, -0.0366, -0.0364, -0.0337, ...]
#     ├── 43
#     │   └── Well
#     │       ├── id = F4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 85ced826-a3ea-4e2d-8a8e-8d6b26608223
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = fe5fa69e-fd28-4005-a799-e9ac5df7ec0c
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0556, -0.053, -0.0549, -0.0547, -0.0534, ...]
#     ├── 44
#     │   └── Well
#     │       ├── id = F5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = d6c1c7ec-1df2-45ef-ae12-ec018b6b9544
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 713d7459-520f-4b42-a54f-c6a15e0832cf
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0265, -0.026, -0.0276, -0.029, -0.0286, ...]
#     ├── 45
#     │   └── Well
#     │       ├── id = F6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 1eb532f6-62ac-4cc3-8468-35f96218983e
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = be7cc0a6-f15f-4fee-969d-83319fb00354
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.5764, 0.5757, 0.5733, 0.5688, 0.5673, ...]
#     ├── 46
#     │   └── Well
#     │       ├── id = F7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 0b70425c-bc27-4f32-94ed-c9cbbafd1cfd
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = b38372aa-1e99-4bdd-88a9-55248970611d
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.8005, 1.7958, 1.7904, 1.7829, 1.7776, ...]
#     ├── 47
#     │   └── Well
#     │       ├── id = H9
#     │       ├── ph = 450.0
#     │       ├── x_pos = 8
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 8aceb83f-071b-47c9-ae05-49ad86ea5fb3
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 74687036-3f54-44ed-9d5d-729a052e0f1c
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.0639, 3.044, 3.0576, 3.0625, 3.0678, ...]
#     ├── 48
#     │   └── Well
#     │       ├── id = F10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 74bd127b-43e2-461d-a246-0979214e0989
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 3f203d4a-5cfd-4cd8-b190-b9ab229a88d6
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.91, 2.8975, 2.9074, 2.9117, 2.9156, ...]
#     ├── 49
#     │   └── Well
#     │       ├── id = F12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 5
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = f61f7ac6-7e18-40fc-92f8-e7e54955db0e
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 4fe584ee-419a-4d50-924b-f1150ae392c9
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0515, -0.0484, -0.0475, -0.0481, -0.0479, ...]
#     ├── 50
#     │   └── Well
#     │       ├── id = G4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 21b0962f-f3f1-4842-a362-0d6337de8513
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = cec5804a-ddb6-4e1c-b341-a84829e465c9
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0524, -0.0506, -0.0509, -0.0503, -0.0497, ...]
#     ├── 51
#     │   └── Well
#     │       ├── id = G5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 6f328cdf-ceea-4a01-a0dd-950a01c44ac6
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 0863b506-fc8b-40d5-8b9e-f3b0b79691ed
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0322, -0.0319, -0.0318, -0.0355, -0.0353, ...]
#     ├── 52
#     │   └── Well
#     │       ├── id = G6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 33a2b744-e5f6-4890-8e68-133e84a1019c
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 9fd60a86-445d-4a28-a3e3-b67966391f41
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.5653, 0.5621, 0.5584, 0.5542, 0.5517, ...]
#     ├── 53
#     │   └── Well
#     │       ├── id = G7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 0c19f757-4c2f-4101-b3c5-42620a9b9843
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 61f381b5-8950-4ebe-8135-6ed3711e9344
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.8494, 1.8439, 1.8352, 1.8284, 1.8206, ...]
#     ├── 54
#     │   └── Well
#     │       ├── id = G10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = c68af5f9-fcdf-4dc8-b703-48d92489d93c
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 2a76b5df-660e-403c-89c7-cfc8304d877a
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [2.9616, 2.9549, 2.9625, 2.953, 2.9618, ...]
#     ├── 55
#     │   └── Well
#     │       ├── id = G12
#     │       ├── ph = 450.0
#     │       ├── x_pos = 11
#     │       ├── y_pos = 6
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 33d45fc9-66d5-4f55-a8ec-766becf09ef4
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 7221c9ec-e2ea-437e-9d0b-650e15c35bb5
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0484, -0.0434, -0.0413, -0.0396, -0.0384, ...]
#     ├── 56
#     │   └── Well
#     │       ├── id = H4
#     │       ├── ph = 450.0
#     │       ├── x_pos = 3
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 30687cd7-7034-433b-ad34-b57f3a0c6831
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = fa552dad-22d3-49b0-b3fb-a933ba368b7d
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.052, -0.051, -0.0502, -0.0507, -0.0513, ...]
#     ├── 57
#     │   └── Well
#     │       ├── id = H5
#     │       ├── ph = 450.0
#     │       ├── x_pos = 4
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 4dcb98a5-919b-43a8-ac1b-a9f483785be3
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = e27c4fe2-6e64-4ad8-8688-c7b8fb3e675e
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [-0.0374, -0.0372, -0.0381, -0.0399, -0.0397, ...]
#     ├── 58
#     │   └── Well
#     │       ├── id = H6
#     │       ├── ph = 450.0
#     │       ├── x_pos = 5
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = fe5c21b7-d3ef-4d80-bc9a-96a55e4551c9
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = 0561a333-9f6e-4159-8ed2-11deb6fbc765
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [0.5552, 0.5537, 0.5511, 0.5456, 0.5429, ...]
#     ├── 59
#     │   └── Well
#     │       ├── id = H7
#     │       ├── ph = 450.0
#     │       ├── x_pos = 6
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = 29f9d3c0-a668-4a82-9394-24c92c545ca6
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = c65a5e03-b38a-4e14-a4f7-0834c2b25f29
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [1.7858, 1.783, 1.7756, 1.7658, 1.7582, ...]
#     ├── 60
#     │   └── Well
#     │       ├── id = H10
#     │       ├── ph = 450.0
#     │       ├── x_pos = 9
#     │       ├── y_pos = 7
#     │       └── measurements
#     │           └── 0
#     │               └── PhotometricMeasurement
#     │                   ├── id = d10d309c-011b-483f-b992-445fd839a376
#     │                   ├── wavelength = 7.0
#     │                   ├── wavelength_unit
#     │                   │   └── Unit
#     │                   │       ├── id = ac308acd-0538-4f8f-b939-ba6481552a33
#     │                   │       ├── name = nm
#     │                   │       └── bases
#     │                   │           └── 0
#     │                   │               └── BaseUnit
#     │                   │                   ├── scale = 1e-09
#     │                   │                   ├── kind = m
#     │                   │                   └── exponent = 1.0
#     │                   └── absorption = [3.0814, 3.0656, 3.0821, 3.0776, 3.086, ...]
#     └── 61
#         └── Well
#             ├── id = H12
#             ├── ph = 450.0
#             ├── x_pos = 11
#             ├── y_pos = 7
#             └── measurements
#                 └── 0
#                     └── PhotometricMeasurement
#                         ├── id = 98aca794-5c56-44c5-a638-1a900733db10
#                         ├── wavelength = 7.0
#                         ├── wavelength_unit
#                         │   └── Unit
#                         │       ├── id = 267899fd-9ac6-4d42-9c7e-5e45e7d51085
#                         │       ├── name = nm
#                         │       └── bases
#                         │           └── 0
#                         │               └── BaseUnit
#                         │                   ├── scale = 1e-09
#                         │                   ├── kind = m
#                         │                   └── exponent = 1.0
#                         └── absorption = [-0.053, -0.0519, -0.0515, -0.0506, -0.0505, ...]
