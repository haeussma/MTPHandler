# %%
import numpy as np

# %reload_ext autoreload
# %autoreload 2

from PlateHandler.modified.plate import Plate
from PlateHandler.ioutils.measurementmapper import create_enzymeml, EnzymeML

# %%
path = "/Users/max/Documents/enzymeml/alaric/EnzymeML_SLAC_5xConcentration_pH2.0-3.5/ABTS_EnzymeML_340nm_420nm_5x_35deg_pH3.5.txt"
time = np.linspace(0, 15, 31)
time_unit = "min"

# Load plate data
plate = Plate.from_file(path, time, time_unit)

# Define species
buffer = plate.add_reactant(id="s1", name="buffer", constant=True)
abts = plate.add_reactant(id="s0", name="ABTS", constant=False,
                          inchi="InChI=1S/C18H18N4O6S4/c1-3-21-13-7-5-11(31(23,24)25)9-15(13)29-17(21)19-20-18-22(4-2)14-8-6-12(32(26,27)28)10-16(14)30-18/h5-10H,3-4H2,1-2H3,(H,23,24,25)(H,26,27,28)/b19-17-,20-18+")
slac = plate.add_protein(id="p0", name="SLAC",
                         constant=True, sequence="MSSKSKPKDVKV")

# Define well conditions for each species
# Define buffer concentration
plate.assign_species_conditions_to_rows(
    row_ids=["A", "B", "C", "D", "E", "F"],
    species=buffer,
    init_concs=100,
    conc_unit="umol / l"
)

# Define substrate concentrations
plate.assign_species_conditions_to_rows(
    row_ids=["A", "B", "C", "D", "E", "F"],
    species=abts,
    init_concs=[0, 5, 10, 15, 25, 50, 75, 100, 150, 200],
    conc_unit="umol / l"
)

# Define enzyme concentrations
plate.assign_species_conditions_to_rows(
    row_ids=["A", "B", "C"],
    species=slac,
    init_concs=4,
    conc_unit="umol / l"
)

# Blank data
plate.blank_species(buffer, 340)
plate.blank_species(slac, 340)

# %% [markdown]
# ### Create `EnzymeMLDocument` based on a `Plate`

# %%
enzymeml_document = create_enzymeml(
    name="ABTS reaction",
    plate=plate,
    reactant=abts,
    protein=slac,
    wavelength=340
)

print(enzymeml_document)
# Out:
# Protein
# ├── id = p0
# ├── name = SLAC
# ├── vessel_id = plate0
# ├── constant = True
# ├── sequence = MSSKSKPKDVKV
# └── ontology = SBO:0000013
#
# EnzymeMLDocument
# ├── id = enzymemldocument1
# ├── name = ABTS reaction
# ├── created = 2023-09-12 21:12:06.615840
# ├── vessels
# │   └── 0
# │       └── Vessel
# │           ├── id = plate0
# │           ├── name = MTP 96 well
# │           ├── volume = 200.0
# │           ├── unit = ul
# │           └── constant = True
# ├── proteins
# │   └── 0
# │       └── Protein
# │           ├── id = p0
# │           ├── name = SLAC
# │           ├── vessel_id = plate0
# │           ├── constant = True
# │           ├── sequence = MSSKSKPKDVKV
# │           └── ontology = SBO:0000013
# ├── reactants
# │   ├── 0
# │   │   └── Reactant
# │   │       ├── id = s1
# │   │       ├── name = buffer
# │   │       ├── vessel_id = plate0
# │   │       ├── constant = True
# │   │       └── ontology = SBO:0000247
# │   └── 1
# │       └── Reactant
# │           ├── id = s0
# │           ├── name = ABTS
# │           ├── vessel_id = plate0
# │           ├── constant = False
# │           ├── inchi = InChI=1S/C18H18N4O6S4/c1-3-21-13-7-5-11(31(23,24)25)9-15(13)29-17(21)19-20-18-22(4-2)14-8-6-12(32(26,27)28)10-16(14)30-18/h5-10H,3-4H2,1-2H3,(H,23,24,25)(H,26,27,28)/b19-17-,20-18+
# │           └── ontology = SBO:0000247
# └── measurements
#     ├── 0
#     │   └── Measurement
#     │       ├── id = measurement9
#     │       ├── name = ABTS 5.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata27
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement9
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata28
#     │       │   │       ├── init_conc = 5.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement9
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A2
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement9
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.03167504036421813, 0.027808682337446114, 0.02309070668715614, 0.023191015663831124, 0.022758560158466126, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B2
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement9
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.033298547172047124, 0.026069207619745113, 0.026637092005616134, 0.027424430146522114, 0.037539256343094116, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C2
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement9
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [0.06304763847272112, 0.05701079320615314, 0.05372070290740112, 0.055716041681811115, 0.05907080466128513, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata29
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement9
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 1
#     │   └── Measurement
#     │       ├── id = measurement10
#     │       ├── name = ABTS 10.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata30
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement10
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata31
#     │       │   │       ├── init_conc = 10.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement10
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A3
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement10
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.09738230252320713, 0.08842690855629913, 0.08126403555265711, 0.07766850475711813, 0.07788066279896312, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B3
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement10
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.11460326451234414, 0.10513857627148314, 0.10086796897574311, 0.09774166970326913, 0.1045695999908781, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C3
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement10
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [0.13559646575351314, 0.12936995463473816, 0.12750268636801515, 0.12582656520672514, 0.12550239795627016, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata32
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement10
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 2
#     │   └── Measurement
#     │       ├── id = measurement11
#     │       ├── name = ABTS 15.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata33
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement11
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata34
#     │       │   │       ├── init_conc = 15.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement11
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A4
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement11
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.18671052141633115, 0.16462623051759512, 0.15473440672565614, 0.15168647475614216, 0.14927972847030713, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B4
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement11
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.21061269508761815, 0.19660252212958113, 0.18700658420092614, 0.18242237690981317, 0.18295641861960316, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C4
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement11
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [0.21680271876764912, 0.20403058995543116, 0.19798282298682113, 0.20211586093669615, 0.20010962987127412, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata35
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement11
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 3
#     │   └── Measurement
#     │       ├── id = measurement12
#     │       ├── name = ABTS 25.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata36
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement12
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata37
#     │       │   │       ├── init_conc = 25.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement12
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A5
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement12
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.34388798597451514, 0.3306757168860691, 0.3169229624841761, 0.3117885917290301, 0.30539323646906813, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B5
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement12
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.39802331901949617, 0.3765492744716141, 0.3675318950274111, 0.3699266692722182, 0.3644663889865951, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C5
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement12
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [0.3989434193202681, 0.3775446138967712, 0.35962911650670915, 0.36281119754343516, 0.35112178427499713, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata38
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement12
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 4
#     │   └── Measurement
#     │       ├── id = measurement13
#     │       ├── name = ABTS 50.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata39
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement13
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata40
#     │       │   │       ├── init_conc = 50.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement13
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A6
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement13
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.8218072149792292, 0.7784879049748431, 0.7466985436004482, 0.7235992754187022, 0.6990941666635572, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B6
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement13
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [0.8604478702683901, 0.8195139309390691, 0.7821998913297051, 0.7598487684680582, 0.7404751794353511, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C6
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement13
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [0.8787160921315201, 0.8312695302565491, 0.7982562437579961, 0.7748143247666361, 0.7527316469001941, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata41
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement13
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 5
#     │   └── Measurement
#     │       ├── id = measurement14
#     │       ├── name = ABTS 75.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata42
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement14
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata43
#     │       │   │       ├── init_conc = 75.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement14
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A7
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement14
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [1.20710280045204, 1.12995979900966, 1.0750529774117001, 1.03997356443739, 0.9876746277189601, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B7
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement14
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [1.29692022151518, 1.21964272033757, 1.16065779609984, 1.11563153014969, 1.07700617809215, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C7
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement14
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [1.28085315796661, 1.19469552832753, 1.13698114457453, 1.08793368853092, 1.05243965857569, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata44
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement14
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 6
#     │   └── Measurement
#     │       ├── id = measurement15
#     │       ├── name = ABTS 100.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata45
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement15
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata46
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement15
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A8
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement15
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [1.80990600389441, 1.70130589964704, 1.6152957697913, 1.52387728253974, 1.48456117571924, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B8
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement15
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [1.9360642281903102, 1.80373561641919, 1.7239730268317701, 1.66890338831776, 1.60202660290221, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C8
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement15
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [1.93420493743259, 1.80129180096696, 1.7253038429611, 1.65838805111659, 1.61867739018394, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata47
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement15
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     ├── 7
#     │   └── Measurement
#     │       ├── id = measurement16
#     │       ├── name = ABTS 150.0 umol / l
#     │       ├── temperature = 35.0
#     │       ├── temperature_unit = C
#     │       ├── ph = 2.0
#     │       ├── species
#     │       │   ├── 0
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata48
#     │       │   │       ├── init_conc = 100.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement16
#     │       │   │       └── species_id = s1
#     │       │   ├── 1
#     │       │   │   └── MeasurementData
#     │       │   │       ├── id = measurementdata49
#     │       │   │       ├── init_conc = 150.0
#     │       │   │       ├── unit = umol / l
#     │       │   │       ├── measurement_id = measurement16
#     │       │   │       ├── species_id = s0
#     │       │   │       └── replicates
#     │       │   │           ├── 0
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = A9
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement16
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [2.3364788559902, 2.20199136082444, 2.10729794859856, 2.0244471452475503, 1.9655457129806102, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           ├── 1
#     │       │   │           │   └── Replicate
#     │       │   │           │       ├── id = B9
#     │       │   │           │       ├── species_id = s0
#     │       │   │           │       ├── measurement_id = measurement16
#     │       │   │           │       ├── data_type = abs
#     │       │   │           │       ├── data_unit = dimensionless
#     │       │   │           │       ├── time_unit = min
#     │       │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │           │       ├── data = [2.4318090401120704, 2.28698959703647, 2.17734328507589, 2.11414923012458, 1.9906737576439602, ...]
#     │       │   │           │       └── is_calculated = False
#     │       │   │           └── 2
#     │       │   │               └── Replicate
#     │       │   │                   ├── id = C9
#     │       │   │                   ├── species_id = s0
#     │       │   │                   ├── measurement_id = measurement16
#     │       │   │                   ├── data_type = abs
#     │       │   │                   ├── data_unit = dimensionless
#     │       │   │                   ├── time_unit = min
#     │       │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       │   │                   ├── data = [2.35247012679755, 2.2090151443514, 2.1383349489419103, 2.0464117800803403, 1.9988013452945301, ...]
#     │       │   │                   └── is_calculated = False
#     │       │   └── 2
#     │       │       └── MeasurementData
#     │       │           ├── id = measurementdata50
#     │       │           ├── init_conc = 4.0
#     │       │           ├── unit = umol / l
#     │       │           ├── measurement_id = measurement16
#     │       │           └── species_id = p0
#     │       ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#     │       └── global_time_unit = min
#     └── 8
#         └── Measurement
#             ├── id = measurement17
#             ├── name = ABTS 200.0 umol / l
#             ├── temperature = 35.0
#             ├── temperature_unit = C
#             ├── ph = 2.0
#             ├── species
#             │   ├── 0
#             │   │   └── MeasurementData
#             │   │       ├── id = measurementdata51
#             │   │       ├── init_conc = 100.0
#             │   │       ├── unit = umol / l
#             │   │       ├── measurement_id = measurement17
#             │   │       └── species_id = s1
#             │   ├── 1
#             │   │   └── MeasurementData
#             │   │       ├── id = measurementdata52
#             │   │       ├── init_conc = 200.0
#             │   │       ├── unit = umol / l
#             │   │       ├── measurement_id = measurement17
#             │   │       ├── species_id = s0
#             │   │       └── replicates
#             │   │           ├── 0
#             │   │           │   └── Replicate
#             │   │           │       ├── id = A10
#             │   │           │       ├── species_id = s0
#             │   │           │       ├── measurement_id = measurement17
#             │   │           │       ├── data_type = abs
#             │   │           │       ├── data_unit = dimensionless
#             │   │           │       ├── time_unit = min
#             │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#             │   │           │       ├── data = [3.08930035186669, 2.8221673634380005, 2.88232315836628, 2.70682560341113, 2.6714697930513904, ...]
#             │   │           │       └── is_calculated = False
#             │   │           ├── 1
#             │   │           │   └── Replicate
#             │   │           │       ├── id = B10
#             │   │           │       ├── species_id = s0
#             │   │           │       ├── measurement_id = measurement17
#             │   │           │       ├── data_type = abs
#             │   │           │       ├── data_unit = dimensionless
#             │   │           │       ├── time_unit = min
#             │   │           │       ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#             │   │           │       ├── data = [3.0731223305877102, 2.86062561525718, 2.8748237275375903, 2.76152005867957, 2.68284449227212, ...]
#             │   │           │       └── is_calculated = False
#             │   │           └── 2
#             │   │               └── Replicate
#             │   │                   ├── id = C10
#             │   │                   ├── species_id = s0
#             │   │                   ├── measurement_id = measurement17
#             │   │                   ├── data_type = abs
#             │   │                   ├── data_unit = dimensionless
#             │   │                   ├── time_unit = min
#             │   │                   ├── time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#             │   │                   ├── data = [2.86788180979606, 2.6775362273091403, 2.7581638249599503, 2.6725664968713203, 2.6400485927044604, ...]
#             │   │                   └── is_calculated = False
#             │   └── 2
#             │       └── MeasurementData
#             │           ├── id = measurementdata53
#             │           ├── init_conc = 4.0
#             │           ├── unit = umol / l
#             │           ├── measurement_id = measurement17
#             │           └── species_id = p0
#             ├── global_time = [0.0, 0.5, 1.0, 1.5, 2.0, ...]
#             └── global_time_unit = min
