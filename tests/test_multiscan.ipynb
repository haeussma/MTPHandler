# %%
# %reload_ext autoreload
# %autoreload 2
from MTPHandler.core import Plate
from MTPHandler.readers import read_multiskan
import numpy as np

# %%
p = Plate.from_reader(
    read_multiskan,
    path="ABTS_EnzymeML_340nm_420nm_2.5x_pH3_25deg.txt",
    time=np.linspace(0, 15, 31),
    ph=2,
    time_unit="h",
)

p.visualize(wavelengths=340)
# Out:
# 2
