# %%
from sdRDM.generator import generate_python_api

generate_python_api("specifications/photometry.md", "MTPHandler", ".")
# Out:
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# Error processing line 1 of /Users/max/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored

# %%
from MTPHandler.core import Plate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from MTPHandler.core import Plate
#
# File ~/Documents/GitHub/MTPHandler/MTPHandler/core/__init__.py:1
# ----> 1 from .plate import Plate
#       2 from .well import Well
#       3 from .photometricmeasurement import PhotometricMeasurement
#
# File ~/Documents/GitHub/MTPHandler/MTPHandler/core/plate.py:23
#      21 from CaliPytion.core import Standard, SignalType
#      22 from CaliPytion.tools import Calibrator
# ---> 23 from MTPHandler.ioutils import initialize_calibrator
#      24 from .initcondition import InitCondition
#      25 from .well import Well
#
# File ~/Documents/GitHub/MTPHandler/MTPHandler/ioutils/__init__.py:1
# ----> 1 from .calipytion import initialize_calibrator
#
# File ~/Documents/GitHub/MTPHandler/MTPHandler/ioutils/calipytion.py:6
#       4 from CaliPytion.core import Standard, Sample, SignalType
#       5 from CaliPytion.tools import Calibrator
# ----> 6 from MTPHandler.core.abstractspecies import AbstractSpecies
#       7 from MTPHandler.core.well import Well
#       8 from MTPHandler.core.protein import Protein
#
# File ~/Documents/GitHub/MTPHandler/MTPHandler/core/abstractspecies.py:15
#      10 from sdRDM.tools.utils import elem2dict
#      11 from .vessel import Vessel
#      14 @forge_signature
# ---> 15 class AbstractSpecies(sdRDM.DataModel):
#      16     """This object is used to inherit basic attributes common to all species used in the data model."""
#      18     id: Optional[str] = attr(
#      19         name="id",
#      20         description="Unique identifier of the given object.",
#      21         default_factory=lambda: str(uuid4()),
#      22         xml="@id",
#      23     )
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/model.py:268, in XmlModelMeta.__new__(mcls, name, bases, namespace, **kwargs)
#     266 cls = typing.cast(Type['BaseXmlModel'], super().__new__(mcls, name, bases, namespace, **kwargs))
#     267 if not is_abstract:
# --> 268     cls.__build_serializer__()
#     270 return cls
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/model.py:339, in BaseXmlModel.__build_serializer__(cls)
#     336     utils.register_nsmap(cls.__xml_nsmap__)
#     338 if cls.__pydantic_complete__:  # checks that all forward refs are resolved
# --> 339     serializer = Serializer.parse_core_schema(
#     340         schema=cls.__pydantic_core_schema__,
#     341         ctx=Serializer.Context(
#     342             model_name=cls.__name__,
#     343             namespaced_attrs=cls.__xml_ns_attrs__,
#     344             search_mode=cls.__xml_search_mode__,
#     345             entity_info=XmlEntityInfo(
#     346                 EntityLocation.ELEMENT,
#     347                 path=cls.__xml_tag__,
#     348                 ns=cls.__xml_ns__,
#     349                 nsmap=cls.__xml_nsmap__,
#     350             ),
#     351         ),
#     352     )
#     353     assert isinstance(serializer, BaseModelSerializer), "unexpected serializer type"
#     354     cls.__xml_serializer__ = serializer
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/serializer.py:180, in Serializer.parse_core_schema(cls, schema, ctx)
#     177 @classmethod
#     178 def parse_core_schema(cls, schema: pcs.CoreSchema, ctx: Context) -> 'Serializer':
#     179     schema, ctx = cls.preprocess_schema(schema, ctx)
# --> 180     return cls.select_serializer(schema, ctx)
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/serializer.py:237, in Serializer.select_serializer(cls, schema, ctx)
#     235 elif type_family is SchemaTypeFamily.MODEL:
#     236     schema = typing.cast(pcs.ModelSchema, schema)
# --> 237     return factories.model.from_core_schema(schema, ctx)
#     239 elif type_family is SchemaTypeFamily.HOMOGENEOUS_COLLECTION:
#     240     schema = typing.cast(factories.homogeneous.HomogeneousCollectionTypeSchema, schema)
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/factories/model.py:420, in from_core_schema(schema, ctx)
#     418         return RootModelSerializer.from_core_schema(schema, ctx)
#     419     else:
# --> 420         return ModelSerializer.from_core_schema(schema, ctx)
#     422 else:
#     423     if ctx.entity_location in (EntityLocation.ELEMENT, None):
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/factories/model.py:91, in ModelSerializer.from_core_schema(cls, schema, ctx)
#      84         entity_info = None
#      86     field_ctx = ctx.child(
#      87         field_name=field_name,
#      88         field_alias=field_alias,
#      89         entity_info=entity_info,
#      90     )
# ---> 91     fields_serializers[field_name] = Serializer.parse_core_schema(model_field['schema'], field_ctx)
#      93 for model_field in fields_schema['computed_fields']:
#      94     field_name = model_field['property_name']
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/serializer.py:180, in Serializer.parse_core_schema(cls, schema, ctx)
#     177 @classmethod
#     178 def parse_core_schema(cls, schema: pcs.CoreSchema, ctx: Context) -> 'Serializer':
#     179     schema, ctx = cls.preprocess_schema(schema, ctx)
# --> 180     return cls.select_serializer(schema, ctx)
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/serializer.py:257, in Serializer.select_serializer(cls, schema, ctx)
#     255 elif type_family is SchemaTypeFamily.UNION:
#     256     schema = typing.cast(pcs.UnionSchema, schema)
# --> 257     return factories.union.from_core_schema(schema, ctx)
#     259 elif type_family is SchemaTypeFamily.TAGGED_UNION:
#     260     schema = typing.cast(pcs.TaggedUnionSchema, schema)
#
# File ~/miniconda3/envs/mtp-pydantic-v2/lib/python3.12/site-packages/pydantic_xml/serializers/factories/union.py:144, in from_core_schema(schema, ctx)
#     140 assert len(choice_families) > 0, "union choices are not provided"
#     142 if (SchemaTypeFamily.PRIMITIVE in choice_families or SchemaTypeFamily.IS_INSTANCE in choice_families) and \
#     143         SchemaTypeFamily.MODEL in choice_families:
# --> 144     raise TypeError("unions of combined primitive and model types are not supported")
#     146 choice_family = choice_families.pop()
#     147 if choice_family is SchemaTypeFamily.MODEL:
#
# TypeError: unions of combined primitive and model types are not supported
